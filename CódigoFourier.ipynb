# %% [markdown]
# # Codigo Métodos matemáticos punto 4
# En este codigo se hara la expansión en series de fourier de la función x entre -pi y pi.
# Se graficarán las sumatorias respectivas para los valores n=2,5,10,20,30

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x=linspace(-3*pi,3*pi,200)

# %% [markdown]
# ### Para n=2

# %%
def funcionX(n,x):
    return -2*((-1)**n)*sin(n*x)/n

# %%
i=1
y2=linspace(0,0,200)
y2
while (i<=2):
    y2=y2+funcionX(i,x)
    i=i+1

# %%
x1=linspace(-pi,pi,100)
y=x1
plt.plot(x,y2,c='blue', label='n=2')
plot(x1,y, c='green', label='f(x)=x')
legend(loc=0)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Expansión fourier de x entre -pi y pi para x con 2 terminos')
plt.savefig('n2.png')

# %% [markdown]
# ### Para n=5

# %%
i=1
y5=linspace(0,0,200)
while(i<=5):
    y5=y5+funcionX(i,x)
    i=i+1

# %%
plt.plot(x,y5,c='blue', label='n=5')
plot(x1,y, c='green', label='f(x)=x')
legend(loc=0)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Expansión fourier de x entre -pi y pi para x con 5 terminos')
plt.savefig('n5.png')

# %% [markdown]
# ### Para n=10

# %%
i=1
y10=linspace(0,0,200)
while(i<=10):
    y10=y10+funcionX(i,x)
    i=i+1

# %%
plt.plot(x,y10,c='blue', label='n=10')
plot(x1,y, c='green', label='f(x)=x')
legend(loc=0)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Expansión fourier de x entre -pi y pi para x con 10 terminos')
plt.savefig('n10.png')

# %% [markdown]
# ### Para n=20

# %%
i=1
y20=linspace(0,0,200)
while(i<=20):
    y20=y20+funcionX(i,x)
    i=i+1

# %%
plt.plot(x,y20,c='blue', label='n=20')
plot(x1,y, c='green', label='f(x)=x')
legend(loc=0)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Expansión fourier de x entre -pi y pi para x con 20 terminos')
plt.savefig('n20.png')

# %% [markdown]
# ### Para n=30

# %%
i=1
y30=linspace(0,0,200)
while(i<=30):
    y30=y30+funcionX(i,x)
    i=i+1

# %%
plt.plot(x,y30,c='blue', label='n=30')
plot(x1,y, c='green', label='f(x)=x')
legend(loc=0)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Expansión fourier de x entre -pi y pi para x con 30 terminos')
plt.savefig('n30.png')

# %% [markdown]
# ### Comparacion

# %%
plot(x,y2, c='green', label='n=2')
plot(x,y5, c='blue', label='n=5')
plot(x,y10, c='red', label='n=10')
plot(x,y20, c='purple', label='n=20')
plot(x,y30, c='black', label='n=30')
plot(x1,y, c='yellow', label='f(x)=x')
legend(loc=0)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Comparacion de las distintas aproximaciones a f(x)=x')
plt.savefig('comparacion.png')

# %% [markdown]
# ## Conclusiones
# Como se puede ver, al aumentar el valor de n, la sumas de los senos se acercan cada vez más a la función x evaluada entre -pi y pi. Se espera que, cuando la función tienda al infinito, esta sea igual a la función x

# %%
x1=linspace(-pi,pi,100)
y=x1

# %%
plot(x1,y)
